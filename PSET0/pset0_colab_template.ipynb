# %% [markdown]
# # PSET 0 — Starter (Colab)
#
# > Tip: Colab runtimes are ephemeral. Re-run the setup cell whenever the session restarts.

# %% [markdown]
# ## 1) Environment setup
# Install runtime deps (edit to match your repo):

# %%
# If your repo has requirements.txt accessible via raw URL, use that:
# %pip install -q -r https://raw.githubusercontent.com/ComputationalRobotics/2025-ES-AM-158-PSET/main/requirements.txt

# Otherwise install minimal set for testing:
# %pip install -q numpy matplotlib tqdm

# %% [markdown]
# ## 2) (Optional) Clone this repo into the runtime

# %%
# !git clone https://github.com/ComputationalRobotics/2025-ES-AM-158-PSET.git || true
# %cd 2025-ES-AM-158-PSET
# !ls -la

# %% [markdown]
# ## 3) Your work starts here

# %%
import numpy as np
print('NumPy OK:', np.__version__)
